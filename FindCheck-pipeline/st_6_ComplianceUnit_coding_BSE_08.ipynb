# %%
your_api_key=" "
your_api_base=" "
your_model_name=" "

# %% [markdown]
# # cu情况

# %%
import pandas as pd

# 读取Excel文件
file_path = "ComplianceUnit_to_code/ComplianceUnit_selected_with_relation_GT/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.xlsx"
df = pd.read_excel(file_path)

# 统计各类别出现次数
type_counts = df['type'].value_counts()

# 计算比例
type_proportions = type_counts / len(df) * 100

# 打印结果
print("各类别统计结果:")
print(type_counts)
print("\n各类别比例(%):")
print(type_proportions)
# Out:
# 各类别统计结果:
# type
# 数值化执行单元                   31
# 为简化模型暂不考虑的单元              30
# 无法简单执行的兜底条款，倡议条款和模糊的条款    30
# 在标准的数据格式下不需额外考虑           11
# 立法宗旨等法律基本信息                4
# 定义类条款                      1
# Name: count, dtype: int64
#
# 各类别比例(%):
# type
# 数值化执行单元                   28.971963
# 为简化模型暂不考虑的单元              28.037383
# 无法简单执行的兜底条款，倡议条款和模糊的条款    28.037383
# 在标准的数据格式下不需额外考虑           10.280374
# 立法宗旨等法律基本信息                3.738318
# 定义类条款                      0.934579
# Name: count, dtype: float64

# %%
cu_to_code_df = df[df['type']=="数值化执行单元"]
print(len(cu_to_code_df))
cu_to_code_df
# Out:
# 31
#       cu_id                                  subject  \
# 8    cu_4_1                            上市公司大股东 | 董监高
# 14   cu_4_7                            上市公司大股东 | 董监高
# 15   cu_4_8                            上市公司大股东 | 董监高
# 29   cu_9_1                       控股股东 | 实际控制人 | 董监高
# 31   cu_9_3                                      董监高
# 32  cu_10_1                                  上市公司大股东
# 33  cu_10_2                                  上市公司大股东
# 34  cu_10_3                                  上市公司大股东
# 37  cu_11_1                         上市公司控股股东 | 实际控制人
# 38  cu_11_2                         上市公司控股股东 | 实际控制人
# 39  cu_11_3                         上市公司控股股东 | 实际控制人
# 40  cu_11_4                         上市公司控股股东 | 实际控制人
# 42  cu_12_1       公开发行股票并上市时的控股股东 | 公开发行股票并上市时的实际控制人
# 43  cu_12_2                 上市公司控股股东 | 实际控制人 | 一致行动人
# 44  cu_12_3                 上市公司控股股东 | 实际控制人 | 一致行动人
# 45  cu_12_4  上市时控股股东 | 上市时实际控制人（上市后不再具备相关主体身份的也应当遵守）
# 46  cu_12_5                公开发行时持股5%以上的第一大股东 | 一致行动人
# 48  cu_13_2                                      大股东
# 49  cu_13_3                             控股股东 | 实际控制人
# 50  cu_14_1                                  上市公司董监高
# 51  cu_14_2                                  上市公司董监高
# 52  cu_14_3                                  上市公司董监高
# 53  cu_14_4                                  上市公司董监高
# 54  cu_14_5                                  上市公司董监高
# 55  cu_14_6                                  上市公司董监高
# 56  cu_14_7                                  上市公司董监高
# 59  cu_16_1                                  上市公司董监高
# 60  cu_16_2                                  上市公司董监高
# 64  cu_17_1                     上市公司董监高 | 离任六个月内的董监高
# 65  cu_17_2                                  上市公司董监高
# 82  cu_23_1                            上市公司大股东 | 董监高
#
#                                             condition  \
# 8                                 计划通过本所集中竞价或大宗交易减持股份
# 14                                             披露减持计划
# 15                    拟在3个月内通过集中竞价交易减持股份的总数超过公司股份总数1%
# 29                                 公司上市时未盈利且处于实现盈利前阶段
# 31                                在前款规定的2个完整会计年度期间内离职
# 32  因涉嫌与本上市公司有关的证券期货违法犯罪，在被中国证监会及其派出机构立案调查或者被司法机关立...
# 33  因涉嫌与本上市公司有关的证券期货违法犯罪被中国证监会及其派出机构立案调查或者被司法机关立案侦...
# 34                      因涉及与本上市公司有关的违法违规，被本所公开谴责未满3个月
# 37     上市公司因涉嫌证券期货违法犯罪，在被中国证监会及其派出机构立案调查或者被司法机关立案侦查期间
# 38  上市公司因涉嫌证券期货违法犯罪被中国证监会及其派出机构立案调查或者被司法机关立案侦查，在行政...
# 39                                   上市公司被本所公开谴责未满3个月
# 40   市公司股票因可能触及重大违法强制退市情形，而被本所实施退市风险警示，在本所规定的限制减持期限内的
# 42  计划通过集中竞价交易或大宗交易减持股份且首次披露减持计划, 且不存在已经按照本指引第四条披露...
# 43  计划通过集中竞价交易或大宗交易减持股份且首次披露减持计划, 且不存在已经按照本指引第四条披露...
# 44  计划通过集中竞价交易或大宗交易减持股份且首次披露减持计划, 且不存在已经按照本指引第四条披露...
# 45  计划通过集中竞价交易或大宗交易减持股份且首次披露减持计划, 且不存在已经按照本指引第四条披露...
# 46  上市公司在公开发行股票并上市时披露为无控股股东、实际控制人, 且计划通过集中竞价交易或大宗交...
# 48             通过协议转让方式减持股份导致出让方不再具有大股东身份, 且处在减持后6个月内
# 49       通过协议转让方式减持股份导致其不再具有控股股东、实际控制人身份, 且处于减持后的6个月内
# 50     上市公司因涉嫌证券期货违法犯罪，在被中国证监会及其派出机构立案调查或者被司法机关立案侦查期间
# 51  上市公司因涉嫌证券期货违法犯罪被中国证监会及其派出机构立案调查或者被司法机关立案侦查，在行政...
# 52  本人因涉嫌与该上市公司有关的证券期货违法犯罪，在被中国证监会及其派出机构立案调查或者被司法机...
# 53  本人因涉嫌与该上市公司有关的证券期货违法犯罪被中国证监会及其派出机构立案调查或者被司法机关立...
# 54  本人因涉及证券期货违法，被中国证监会行政处罚，罚没款尚未足额缴纳，且不存在法律、行政法规另有...
# 55                 本人因涉及与本上市公司有关的违法违规，被证券交易所公开谴责未满三个月
# 56  上市公司股票因可能触及重大违法强制退市情形而被本所实施退市风险警示，且处于本所规定的限制转让...
# 59                              上市公司年度报告、半年度报告公告前15日内
# 60                           上市公司季度报告、业绩预告、业绩快报公告前5日内
# 64  每年通过集中竞价、大宗交易、协议转让等方式转让股份且不属于因司法强制执行、继承、遗赠、依法分...
# 65                                       所持股份不超过1000股
# 82                                                NaN
#
#                                            constraint  \
# 8               应当及时通知公司，并在首次卖出的15个交易日前向本所报告并预先披露减持计划
# 14                            每次披露的减持计划中减持时间区间不得超过3个月
# 15                            应当在首次卖出的30个交易日前预先披露减持计划
# 29                  自公司股票上市之日起2个完整会计年度内不得减持公开发行并上市前股份
# 31                                    应当继续遵守前款规定的减持限制
# 32                                     不得减持其所持有的本公司股份
# 33                                     不得减持其所持有的本公司股份
# 34                                     不得减持其所持有的本公司股份
# 37                                     不得减持其所持有的本公司股份
# 38                                     不得减持其所持有的本公司股份
# 39                                     不得减持其所持有的本公司股份
# 40                                     不得减持其所持有的本公司股份
# 42       不得存在下列情形：最近20个交易日内任一交易日股票收盘价低于公开发行股票并上市的发行价格
# 43  不得存在下列情形：最近20个交易日内，上市公司任一交易日股票收盘价低于最近一个会计年度或者最...
# 44          不得存在下列情形：上市公司最近一期经审计的财务报告的归属于上市公司股东的净利润为负
# 45       不得存在下列情形：最近20个交易日内任一交易日股票收盘价低于公开发行股票并上市的发行价格
# 46       不得存在下列情形：最近20个交易日内任一交易日股票收盘价低于公开发行股票并上市的发行价格
# 48                                       继续遵守本指引第四条规定
# 49                            应当继续遵守本指引第十二条第一款第二、三项规定
# 50                                     不得减持其所持有的本公司股份
# 51                                     不得减持其所持有的本公司股份
# 52                                     不得减持其所持有的本公司股份
# 53                                     不得减持其所持有的本公司股份
# 54                                     不得减持其所持有的本公司股份
# 55                                     不得减持其所持有的本公司股份
# 56                                     不得减持其所持有的本公司股份
# 59                                          不得买卖本公司股份
# 60                                          不得买卖本公司股份
# 64                          每年转让的股份不得超过其所持本公司股份总数的25%
# 65                                 可一次全部转让且不受前款转让比例限制
# 82                                        不得融券卖出本公司股份
#
#                                 contextual_info        relation  \
# 8                                           NaN             NaN
# 14                                          NaN             NaN
# 15                                          NaN             NaN
# 29                                          NaN             NaN
# 31                                          NaN        refer_to
# 32                                          NaN             NaN
# 33                                          NaN             NaN
# 34                                          NaN             NaN
# 37                                          NaN             NaN
# 38                                          NaN             NaN
# 39                                          NaN             NaN
# 40                                          NaN             NaN
# 42                   股票收盘价以公开发行股票并上市之日为基准向后复权计算             NaN
# 43  股票收盘价以最近一个会计年度或者最近一期财务会计报告资产负债表日为基准分别向后复权计算             NaN
# 44                                          NaN             NaN
# 45                   股票收盘价以公开发行股票并上市之日为基准向后复权计算             NaN
# 46                   股票收盘价以公开发行股票并上市之日为基准向后复权计算             NaN
# 48                                          NaN  should_include
# 49                                          NaN  should_include
# 50                                          NaN             NaN
# 51                                          NaN             NaN
# 52                                          NaN             NaN
# 53                                          NaN             NaN
# 54                                          NaN             NaN
# 55                                          NaN             NaN
# 56                                          NaN             NaN
# 59                                          NaN             NaN
# 60                                          NaN             NaN
# 64                                          NaN        refer_to
# 65                                          NaN         exclude
# 82                                          NaN             NaN
#
#                                  target     type  \
# 8                                   NaN  数值化执行单元
# 14                                  NaN  数值化执行单元
# 15                                  NaN  数值化执行单元
# 29                                  NaN  数值化执行单元
# 31                              MEU_9_1  数值化执行单元
# 32                                  NaN  数值化执行单元
# 33                                  NaN  数值化执行单元
# 34                                  NaN  数值化执行单元
# 37                                  NaN  数值化执行单元
# 38                                  NaN  数值化执行单元
# 39                                  NaN  数值化执行单元
# 40                                  NaN  数值化执行单元
# 42                                  NaN  数值化执行单元
# 43                                  NaN  数值化执行单元
# 44                                  NaN  数值化执行单元
# 45                                  NaN  数值化执行单元
# 46                                  NaN  数值化执行单元
# 48                                Law_4  数值化执行单元
# 49                    MEU_12_1;MEU_12_2  数值化执行单元
# 50                                  NaN  数值化执行单元
# 51                                  NaN  数值化执行单元
# 52                                  NaN  数值化执行单元
# 53                                  NaN  数值化执行单元
# 54                                  NaN  数值化执行单元
# 55                                  NaN  数值化执行单元
# 56                                  NaN  数值化执行单元
# 59                                  NaN  数值化执行单元
# 60                                  NaN  数值化执行单元
# 64  MEU_18_1;MEU_18_2;MEU_18_3;MEU_18_4  数值化执行单元
# 65                             MEU_17_1  数值化执行单元
# 82                                  NaN  数值化执行单元
#
#                                              comments  \
# 8                                                 NaN
# 14                                                NaN
# 15                                                NaN
# 29                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 48  涉及到身份转换的条目, 需要人为介入. 此条目的subject应默认正确, 因为其已经蕴含在...
# 49  涉及到身份转换的条目, 需要人为介入. 此条目的subject应默认正确, 因为其已经蕴含在...
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                  暂不处理, 有空再在模拟数据上加上
# 55                                                NaN
# 56                                                NaN
# 59                                                NaN
# 60                                                NaN
# 64                                                NaN
# 65                                                NaN
# 82                                                NaN
#
#                                                  note
# 8                                         不考虑是否及时通知公司
# 14        三个月按照90个自然日计算; 条件"披露减持计划"理解为考察所有存在减持计划的时期.
# 15                                                NaN
# 29  假设"当日减持比例"记录的都是减持"公开发行并上市前获取的股份"; 对condition的进...
# 31         只需要检查subject和condition, 而constraint项留为None
# 32                                                NaN
# 33                              6个月按180个自然日计算, 含处罚日当日
# 34                            三个月按照90个自然日计算, 含处罚日当日;
# 37                                                NaN
# 38                                      6个月按180个自然日计算
# 39                            三个月按照90个自然日计算, 含处罚日当日;
# 40                                                NaN
# 42  不考虑已经按照本指引第四条披露减持计划，或者中国证监会另有规定的情况; 公司上市前30个交易...
# 43  不考虑已经按照本指引第四条披露减持计划，或者中国证监会另有规定的情况; 公司上市的头30个交...
# 44            不考虑中国证监会另有规定的情况; 不考虑一致行动人; 所有财务数据均已经过审计
# 45                                    不考虑中国证监会另有规定的情况
# 46  不考虑中国证监会另有规定的情况; 不考虑一致行动人; 假设数据库固定"公司简称"后, "股东...
# 48  subject项默认为True并且不再处理; 6个月按180个自然日计算, 含处罚日当日; ...
# 49  subject项默认为True并且不再处理; 6个月按180个自然日计算, 含处罚日当日; ...
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                              6个月按180个自然日计算, 含处罚日当日
# 54                      不考虑法律、行政法规另有规定或减持资金用于缴纳罚没款的情况
# 55                            三个月按照90个自然日计算, 含处罚日当日;
# 56                                                NaN
# 59                                                NaN
# 60                                          只考虑季度报告情况
# 64  不考虑因司法强制执行、继承、遗赠、依法分割财产等导致股份变动的情况; 6个月按180个自然日...
# 65                          不需要处理constrain项, 保留其为None
# 82                                                NaN

# %% [markdown]
# # Prompt模板

# %% [markdown]
# ## a. 普通任务 prompt

# %%
prompt_cu_coding_bse_08 = """
# 身份
你是一个精通法律的程序员. 擅长编写代码以检验特定案例对于特定法律要求的合规性. 

## ComplianceUnit概念简述
ComplianceUnit是法律条文拆解出的合规检查单元，包含：
- cu_id: ComplianceUnit的编号, 通常为"cu_n_k", 其中n是其所属的法条的编号, k是其在法条内部的编号
- subject: 责任主体（如"控股股东") 
- condition: 触发条件（如"减持股份")  
- constraint: 约束内容（如"提前15日公告") 
- contextual_info: 补充说明（如价格计算方式）


# 任务
你现在面临一个编写代码以检验某法律事件的合规性的任务, 你需要编写一个函数, 这个函数的输入是一个日频的pandas dataframe, 每一行是在某个交易日内公司的情况和股东的情况, 这个函数会检验该dataframe的每一行在某一个给定的法律合规单元上的合规性, 标注在特定的列上, 并返回标注后的dataframe. 


# 更多要求
 - 你可以进行任意长度的思考, 然后用<CODE></CODE>包裹你的代码. 
 - 你需要按照下面这个框架编写代码: 
  - 1. 标记valid的subject(cu_n_k_subject); (复合subject的行标记为True, 不符合的为False)
  - 2. 标记valid的condition(cu_n_k_condition); (符合condition的行标记为True, 不符合的为False)
  - 3. 标记valid的constraint(cu_n_k_constraint); (符合constraint的行标记为True, 不符合的为False)
  - 4. 在dataframe中记录subject, condition和constraint的valid情况; 
 - 注意: 对于简单操作dataframe就可以处理的项目, 对三元组<subject, conditon, constraint>的检查是各自独立的, 你需要分别标记三元组的True和False. 并不是只对符合subject和condition进行检查. 对于需要调用llm_content_check()函数的项目, 只对符合<subject, conditon>的constraint进行检查. 

# example
下面是一个例子:

## 输入
法律的合规单元编号: cu_4_1
法律的合规单元内容: {{"subject": "上市公司大股东 | 董监高", "condition": "计划通过本所集中竞价或大宗交易减持股份", "constraint": "应当及时通知公司，并在首次卖出的15个交易日前向本所报告并预先披露减持计划", "contextual_info": NaN}}
必要的额外信息: NaN

## 输出
<CODE>
import pandas a pd

def check_cu_4_1(df):
    '''
    检查cu_4_1的合规性：
    主体：上市公司大股东 | 董监高
    条件：存在通过竞价/大宗交易的减持计划
    约束：首次卖出前至少15个交易日披露
    '''
    df = df.copy()

    # 初始化标记列
    df['cu_4_1_subject'] = False
    df['cu_4_1_condition'] = False
    df['cu_4_1_constraint'] = None

    # 1. 验证责任主体
    is_major = (
        df['股东身份'].isin(['控股股东', '实际控制人', '持股5%以上股东']) |
        (df['持股比例'] >= 0.05)
    )
    is_director = df['股东身份'] == '董监高'
    df.loc[is_major | is_director, 'cu_4_1_subject'] = True

    # 2. 验证触发条件
    valid_condition = (
        df['减持方式'].isin(['竞价交易', '大宗交易']) &
        df['存在减持计划']
    )
    df.loc[valid_condition, 'cu_4_1_condition'] = True

    # 3. 核心改进：准确识别首次卖出日
    def process_group(group):
        group = group.sort_values('日期')
        plans = []
        current_plan = None

        # 识别减持计划区间
        for _, row in group.iterrows():
            if row['存在减持计划']:
                if current_plan is None:
                    current_plan = {{
                        '披露日': row['计划披露日'],
                        '开始日': row['计划开始日'],
                        '减持记录': []
                    }}
                if row['当日减持比例'] > 0:
                    current_plan['减持记录'].append(row['日期'])
            else:
                if current_plan:
                    plans.append(current_plan)
                    current_plan = None
        if current_plan:
            plans.append(current_plan)

        # 提取首次卖出日
        return pd.DataFrame([{{
            '公司简称': group['公司简称'].iloc[0],
            '股东': group['股东'].iloc[0],
            '计划披露日': p['披露日'],
            '首次卖出日': min(p['减持记录']) if p['减持记录'] else pd.NaT
        }} for p in plans])

    # 按分组处理并合并
    plan_info = df.groupby(['公司简称', '股东'], group_keys=False).apply(process_group)
    df = df.merge(
        plan_info,
        on=['公司简称', '股东', '计划披露日'],
        how='left'
    ) if not plan_info.empty else df.assign(首次卖出日=pd.NaT)

    # 4. 交易日差计算（改进点：使用首次卖出日而非计划开始日）
    trading_dates = pd.Series(df['日期'].unique()).sort_values().reset_index(drop=True)
    date_map = {{date: idx for idx, date in enumerate(trading_dates)}}

    df['交易日差'] = df.apply(
        lambda x: date_map.get(x['首次卖出日'], np.nan) - date_map.get(x['计划披露日'], np.nan),
        axis=1
    )

    # 5. 验证约束条件
    # 至少提前15个交易日披露
    df['cu_4_1_constraint'] = (df['交易日差'] >= 15)

    return df

</CODE>

# 下面轮到你来完成这个任务
法律的最小可执行单元编号: {cu_id}
法律的最小可执行单元内容: {cu_content}
必要的额外信息: {note}


# 附加信息
## 你可以操作的dataframe的columns: 
['日期', '日收益率', '收盘价', '前收盘价', '上市日期', '发行价格', '净资产增长率', '净利润增长率', '净资产',
'净利润', '总股本', '每股净资产', '每股净利润', '公告类型', '公告日期', '复权因子', '收盘价减每股净资产',
'收盘价减每股净利润', '公司涉嫌证券期货违法犯罪事件', '持股比例', '持股数量', '股东身份', '减持方式', '拟减持原因',
'存在减持计划', '计划减持比例', '计划价格下限', '计划价格上限', '当日减持比例', '累计减持比例', '计划披露日',
'计划开始日', '计划结束日', '离任日期', '公司简称', '股东', '股东涉嫌证券期货违法犯罪事件']

## 其中: 
- 所有公司均为在本交易所上市的上市公司
- 所有日期相关的列都已经是pd.datetime格式, ['日期']列本身就是交易日, 不需要额外计算交易日, 但是自然日需要计算. 
- 所有价格的单位都是元而非万元, 千元或百万元; 所有的比例都是小数而非百分数
- 这是一个二维的面板数据, 根据['日期', '公司简称', '股东']可以定位到特定公司的特定股东在特定交易日的状态, 以及公司在该日的状态. 如果你要分公司和股东地考虑一些合规要求, 需要考虑按照 ['公司简称', '股东']分组并在组内完成. 
- 交易方式有['竞价交易', '大宗交易', '融券卖出'], 竞价交易包括集中竞价. 
- ['公司/股东涉嫌证券期货违法犯罪事件'] 有['被中国证监会及其派出机构立案调查', '中国证监会及其派出机构立案调查结束', '行政处罚决定作出', '被司法机关立案侦查', '司法机关立案侦查结束', '被本所公开谴责']
- ['股东身份'] 有 ['董监高', '离任董监高', '控股股东', '实际控制人', '持股5%以上股东', '普通股东'], 这些标签不会并列出现, 因此有时候董监高/离任董监高持股在5%以上但并没有标明'持股5%以上股东', 你需要从['持股比例']手动筛选. 
- ['存在减持计划']是一个布尔值，表示该股东当天是否有减持计划
- 假设公司上市发行价就是最早的非空的收盘价, 公司发行时的控股股东和实际控制人就是第一个非空的收盘价的同一天的控股股东和实际控制人. 
- ['持股比例'] 全部是公开上市前取得的股份. 不考虑承诺和限制出售的股份. 

"""

# %% [markdown]
# ## b. 含有refer_to的prompt

# %% [markdown]
# 需求: 自动多跳地把所有refer_to的target都直接呈现在prompt里面

# %%
prompt_cu_coding_bse_08_with_refer_to = """
# 身份
你是一个精通法律的程序员. 擅长编写代码以检验特定案例对于特定法律要求的合规性. 

## ComplianceUnit概念简述
ComplianceUnit是法律条文拆解出的合规检查单元，包含：
- cu_id: ComplianceUnit的编号, 通常为"cu_n_k", 其中n是其所属的法条的编号, k是其在法条内部的编号
- subject: 责任主体（如"控股股东") 
- condition: 触发条件（如"减持股份")  
- constraint: 约束内容（如"提前15日公告") 
- contextual_info: 补充说明（如价格计算方式）


# 任务
你现在面临一个编写代码以检验某法律事件的合规性的任务, 你需要编写一个函数, 这个函数的输入是一个日频的pandas dataframe, 每一行是在某个交易日内公司的情况和股东的情况, 这个函数会检验该dataframe的每一行在某一个给定的法律合规单元上的合规性, 标注在特定的列上, 并返回标注后的dataframe. 


# 更多要求
 - 你可以进行任意长度的思考, 然后用<CODE></CODE>包裹你的代码. 
 - 你需要按照下面这个框架编写代码: 
  - 1. 标记valid的subject(cu_n_k_subject); (复合subject的行标记为True, 不符合的为False)
  - 2. 标记valid的condition(cu_n_k_condition); (符合condition的行标记为True, 不符合的为False)
  - 3. 标记valid的constraint(cu_n_k_constraint); (符合constraint的行标记为True, 不符合的为False)
  - 4. 在dataframe中记录subject, condition和constraint的valid情况; 
 - 注意: 对于简单操作dataframe就可以处理的项目, 对三元组<subject, conditon, constraint>的检查是各自独立的, 你需要分别标记三元组的True和False. 并不是只对符合subject和condition进行检查. 对于需要调用llm_content_check()函数的项目, 只对符合<subject, conditon>的constraint进行检查. 

# example
下面是一个例子:

## 输入
法律的合规单元编号: cu_4_1
法律的合规单元内容: {{"subject": "上市公司大股东 | 董监高", "condition": "计划通过本所集中竞价或大宗交易减持股份", "constraint": "应当及时通知公司，并在首次卖出的15个交易日前向本所报告并预先披露减持计划", "contextual_info": NaN}}
必要的额外信息: NaN

## 输出
<CODE>
import pandas a pd

def check_cu_4_1(df):
    '''
    检查cu_4_1的合规性：
    主体：上市公司大股东 | 董监高
    条件：存在通过竞价/大宗交易的减持计划
    约束：首次卖出前至少15个交易日披露
    '''
    df = df.copy()

    # 初始化标记列
    df['cu_4_1_subject'] = False
    df['cu_4_1_condition'] = False
    df['cu_4_1_constraint'] = None

    # 1. 验证责任主体
    is_major = (
        df['股东身份'].isin(['控股股东', '实际控制人', '持股5%以上股东']) |
        (df['持股比例'] >= 0.05)
    )
    is_director = df['股东身份'] == '董监高'
    df.loc[is_major | is_director, 'cu_4_1_subject'] = True

    # 2. 验证触发条件
    valid_condition = (
        df['减持方式'].isin(['竞价交易', '大宗交易']) &
        df['存在减持计划']
    )
    df.loc[valid_condition, 'cu_4_1_condition'] = True

    # 3. 核心改进：准确识别首次卖出日
    def process_group(group):
        group = group.sort_values('日期')
        plans = []
        current_plan = None

        # 识别减持计划区间
        for _, row in group.iterrows():
            if row['存在减持计划']:
                if current_plan is None:
                    current_plan = {{
                        '披露日': row['计划披露日'],
                        '开始日': row['计划开始日'],
                        '减持记录': []
                    }}
                if row['当日减持比例'] > 0:
                    current_plan['减持记录'].append(row['日期'])
            else:
                if current_plan:
                    plans.append(current_plan)
                    current_plan = None
        if current_plan:
            plans.append(current_plan)

        # 提取首次卖出日
        return pd.DataFrame([{{
            '公司简称': group['公司简称'].iloc[0],
            '股东': group['股东'].iloc[0],
            '计划披露日': p['披露日'],
            '首次卖出日': min(p['减持记录']) if p['减持记录'] else pd.NaT
        }} for p in plans])

    # 按分组处理并合并
    plan_info = df.groupby(['公司简称', '股东'], group_keys=False).apply(process_group)
    df = df.merge(
        plan_info,
        on=['公司简称', '股东', '计划披露日'],
        how='left'
    ) if not plan_info.empty else df.assign(首次卖出日=pd.NaT)

    # 4. 交易日差计算（改进点：使用首次卖出日而非计划开始日）
    trading_dates = pd.Series(df['日期'].unique()).sort_values().reset_index(drop=True)
    date_map = {{date: idx for idx, date in enumerate(trading_dates)}}

    df['交易日差'] = df.apply(
        lambda x: date_map.get(x['首次卖出日'], np.nan) - date_map.get(x['计划披露日'], np.nan),
        axis=1
    )

    # 5. 验证约束条件
    # 至少提前15个交易日披露
    df['cu_4_1_constraint'] = (df['交易日差'] >= 15)

    return df

</CODE>

# 下面轮到你来完成这个任务
法律的最小可执行单元编号: {cu_id}
法律的最小可执行单元内容: {cu_content}
必要的额外信息: {note}

你被分配的cu coding任务存在refer_to关系, 你需要参考下面这个cu的必要内容来完成你被安排的任务, 但你不需要直接执行下面的cu: 
{refer_to}


# 附加信息
## 你可以操作的dataframe的columns: 
['日期', '日收益率', '收盘价', '前收盘价', '上市日期', '发行价格', '净资产增长率', '净利润增长率', '净资产',
'净利润', '总股本', '每股净资产', '每股净利润', '公告类型', '公告日期', '复权因子', '收盘价减每股净资产',
'收盘价减每股净利润', '公司涉嫌证券期货违法犯罪事件', '持股比例', '持股数量', '股东身份', '减持方式', '拟减持原因',
'存在减持计划', '计划减持比例', '计划价格下限', '计划价格上限', '当日减持比例', '累计减持比例', '计划披露日',
'计划开始日', '计划结束日', '离任日期', '公司简称', '股东', '股东涉嫌证券期货违法犯罪事件']

## 其中: 
- 所有公司均为在本交易所上市的上市公司
- 所有日期相关的列都已经是pd.datetime格式, ['日期']列本身就是交易日, 不需要额外计算交易日, 但是自然日需要计算. 
- 所有价格的单位都是元而非万元, 千元或百万元; 所有的比例都是小数而非百分数
- 这是一个二维的面板数据, 根据['日期', '公司简称', '股东']可以定位到特定公司的特定股东在特定交易日的状态, 以及公司在该日的状态. 如果你要分公司和股东地考虑一些合规要求, 需要考虑按照 ['公司简称', '股东']分组并在组内完成. 
- 交易方式有['竞价交易', '大宗交易', '融券卖出'], 竞价交易包括集中竞价. 
- ['公司/股东涉嫌证券期货违法犯罪事件'] 有['被中国证监会及其派出机构立案调查', '中国证监会及其派出机构立案调查结束', '行政处罚决定作出', '被司法机关立案侦查', '司法机关立案侦查结束', '被本所公开谴责']
- ['股东身份'] 有 ['董监高', '离任董监高', '控股股东', '实际控制人', '持股5%以上股东', '普通股东'], 这些标签不会并列出现, 因此有时候董监高/离任董监高持股在5%以上但并没有标明'持股5%以上股东', 你需要从['持股比例']手动筛选. 
- ['存在减持计划']是一个布尔值，表示该股东当天是否有减持计划
- 假设公司上市发行价就是最早的非空的收盘价, 公司发行时的控股股东和实际控制人就是第一个非空的收盘价的同一天的控股股东和实际控制人. 
- ['持股比例'] 全部是公开上市前取得的股份. 不考虑承诺和限制出售的股份. 

"""

# %% [markdown]
# ## 附. 处理refer_to的信息

# %%
excel_path = "ComplianceUnit_to_code/ComplianceUnit_selected_with_relation_GT/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.xlsx"
_target_resolver_cache = pd.read_excel(excel_path)
_target_resolver_cache
# Out:
#        cu_id               subject                              condition  \
# 0     cu_1_1                   NaN                                    NaN
# 1     cu_2_1          上市公司股东 | 董监高                            减持其持有的本公司股份
# 2     cu_2_2          上市公司股东 | 董监高  对持股比例、持股数量、持股期限、减持方式、减持比例、减持价格等做出公开承诺
# 3     cu_2_3  上市公司股东 | 实际控制人 | 董监高                                    NaN
# 4     cu_3_1             大股东 | 董监高                                   减持股份
# ..       ...                   ...                                    ...
# 102  cu_27_1                    本所                     上市公司及相关主体违反本指引相关规定
# 103  cu_27_2                    本所   为防止市场发生重大波动，影响市场交易秩序或者损害投资者利益，防范市场风险
# 104  cu_27_3                    本所                       上市公司减持行为涉嫌违反法律法规
# 105  cu_28_1                    本所                                    NaN
# 106  cu_29_1                   NaN                                    NaN
#
#                         constraint  \
# 0                              NaN
# 1    应当遵守法律法规、部门规章、本所业务规则及本指引的相关规定
# 2                     应当严格履行所做出的承诺
# 3             不得通过任何方式或者安排规避本指引的规定
# 4     应当规范、理性、有序，充分关注上市公司及其中小股东的利益
# ..                             ...
# 102                            NaN
# 103                            NaN
# 104                            NaN
# 105                            NaN
# 106                            NaN
#
#                                        contextual_info relation target  \
# 0    为规范北京证券交易所上市公司股东及董监高持股管理和减持股份行为，维护市场秩序，保护投资者合法...      NaN    NaN
# 1                                                  NaN      NaN    NaN
# 2                                                  NaN      NaN    NaN
# 3                                                  NaN      NaN    NaN
# 4                                                  NaN      NaN    NaN
# ..                                                 ...      ...    ...
# 102                   可以对上市公司及相关责任主体采取工作措施、自律监管措施或纪律处分      NaN    NaN
# 103                  可以有序引导减持，依规对违规减持行为、异常交易行为采取相应监管措施      NaN    NaN
# 104                                         可以报中国证监会查处      NaN    NaN
# 105                                          本所负责解释本指引      NaN    NaN
# 106                                        本指引自发布之日起施行      NaN    NaN
#
#                        type             comments note
# 0               立法宗旨等法律基本信息                  NaN  NaN
# 1               立法宗旨等法律基本信息                  NaN  NaN
# 2              为简化模型暂不考虑的单元  暂不考虑上市公司股东存在承诺的情况.   NaN
# 3    无法简单执行的兜底条款，倡议条款和模糊的条款                  NaN  NaN
# 4    无法简单执行的兜底条款，倡议条款和模糊的条款                  NaN  NaN
# ..                      ...                  ...  ...
# 102  无法简单执行的兜底条款，倡议条款和模糊的条款                  NaN  NaN
# 103  无法简单执行的兜底条款，倡议条款和模糊的条款                  NaN  NaN
# 104  无法简单执行的兜底条款，倡议条款和模糊的条款                  NaN  NaN
# 105             立法宗旨等法律基本信息                  NaN  NaN
# 106             立法宗旨等法律基本信息                  NaN  NaN
#
# [107 rows x 10 columns]

# %%
import pandas as pd
import json
import re

# 缓存加载的Excel数据（避免重复读取）
_target_resolver_cache = None
_prompt_dict_cache = None  # 新增：用于缓存prompt_dict

def target_resolver(target_str: str) -> str:
    """优化版target解析器, 支持分号分隔的多cu"""
    global _target_resolver_cache
    
    # 初始化缓存
    if _target_resolver_cache is None:
        excel_path = "ComplianceUnit_to_code/ComplianceUnit_selected_with_relation_GT/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.xlsx"
        _target_resolver_cache = pd.read_excel(excel_path)
    
    df = _target_resolver_cache
    
    # 处理分号分隔的多cu (新增核心逻辑)
    if ';' in target_str:
        cu_list = [s.strip() for s in target_str.split(';') if s.strip()]
        return "\n\n".join([_resolve_single_cu(cu, df) for cu in cu_list])
    
    # 原有单cu处理
    return _resolve_single_cu(target_str, df)

def _resolve_single_cu(target_str: str, df: pd.DataFrame) -> str:
    """处理单个cu或Law的解析"""
    # cu_n_k 格式
    if re.match(r'cu_\d+_\d+', target_str):
        target_row = df[df['cu_id'] == target_str]
        if not target_row.empty:
            row = target_row.iloc[0]
            # 检查是否为需要忽略的类型
            if row['type'] in ["为简化模型暂不考虑的单元", "无法简单执行的兜底条款，倡议条款和模糊的条款"]:
                return ""
            result = _format_cu_info(row)
            if row['relation'] == 'refer_to' and pd.notna(row['target']):
                referred_content = target_resolver(row['target'])
                # 只有当被引用的内容不为空时才添加关联引用
                if referred_content.strip():
                    result += f"\n\n↳ 关联引用：{referred_content}"
            return result
        return f"未找到cu条目：{target_str}"
    
    # Law_n 格式
    elif re.match(r'Law_\d+', target_str):
        law_num = re.match(r'Law_(\d+)', target_str).group(1)
        related_cus = df[df['cu_id'].str.startswith(f'cu_{law_num}_')]
        if not related_cus.empty:
            # 过滤掉需要忽略的类型
            filtered_cus = [
                row for _, row in related_cus.iterrows() 
                if row['type'] not in ["为简化模型暂不考虑的单元", "无法简单执行的兜底条款，倡议条款和模糊的条款"]
            ]
            return "\n\n".join([
                _format_cu_info(row) for row in filtered_cus
            ])
        return f"未找到Law_{law_num}相关cu"
    
    # 其他格式
    return f"参考条目：{target_str}"

def _format_cu_info(row: pd.Series) -> str:
    """修复contextual_info字段的格式化函数"""
    return (
        f"【{row['cu_id']}】\n"
        f"subject: {row['subject']}\n"
        f"condition: {row['condition'] or '无'}\n"
        f"constraint: {row['constraint'] or '无'}\n"
        f"contextual_info: {row['contextual_info'] or '无'}"
    )

def prepare_prompts(
    df: pd.DataFrame,
    base_template: str,
    refer_template: str,
    target_resolver: callable
) -> dict[str, str]:  # 现在返回字典而不是列表
    """
    生成以cu_id为键的prompt字典
    
    参数：
    df: 原始数据框
    base_template: 基础模板
    refer_template: 带参考的模板
    target_resolver: 处理target的函数
    
    返回：
    以cu_id为键，prompt字符串为值的字典
    """
    prompt_dict = {}
    
    for _, row in df[df['type'] == "数值化执行单元"].iterrows():
        cu_id = row['cu_id']
        # 构造基础参数
        params = {
            'cu_id': cu_id,
            'cu_content': json.dumps({
                "subject": row['subject'],
                "condition": row['condition'],
                "constraint": row['constraint'],
                "contextual_info": row['contextual_info']
            }, ensure_ascii=False),
            'note': row['note']
        }
        
        # 选择模板并填充参数
        if row['relation'] == 'refer_to':
            referred_content = target_resolver(row['target'])
            # 只有当被引用的内容不为空时才添加refer_to参数
            if referred_content.strip():
                params['refer_to'] = referred_content
                prompt_dict[cu_id] = refer_template.format(**params)
            else:
                prompt_dict[cu_id] = base_template.format(**params)
        else:
            prompt_dict[cu_id] = base_template.format(**params)
    
    return prompt_dict

# %%
# 生成prompt字典
if _prompt_dict_cache is None:
    _prompt_dict_cache = prepare_prompts(
        df=pd.read_excel("ComplianceUnit_to_code/ComplianceUnit_selected_with_relation_GT/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.xlsx"),
        base_template=prompt_cu_coding_bse_08,
        refer_template=prompt_cu_coding_bse_08_with_refer_to,
        target_resolver=target_resolver
    )

# 从字典生成列表（保持原有代码兼容性）
prompt_list = list(_prompt_dict_cache.values())

# 打印包含refer_to的prompt
for i in prompt_list:
    if "refer_to" in i:
        print('--------------------------------------------------')
        print(i)
# Out:
# --------------------------------------------------
#
# # 身份
# 你是一个精通法律的程序员. 擅长编写代码以检验特定案例对于特定法律要求的合规性.
#
# ## ComplianceUnit概念简述
# ComplianceUnit是法律条文拆解出的合规检查单元，包含：
# - cu_id: ComplianceUnit的编号, 通常为"cu_n_k", 其中n是其所属的法条的编号, k是其在法条内部的编号
# - subject: 责任主体（如"控股股东")
# - condition: 触发条件（如"减持股份")
# - constraint: 约束内容（如"提前15日公告")
# - contextual_info: 补充说明（如价格计算方式）
#
#
# # 任务
# 你现在面临一个编写代码以检验某法律事件的合规性的任务, 你需要编写一个函数, 这个函数的输入是一个日频的pandas dataframe, 每一行是在某个交易日内公司的情况和股东的情况, 这个函数会检验该dataframe的每一行在某一个给定的法律合规单元上的合规性, 标注在特定的列上, 并返回标注后的dataframe.
#
#
# # 更多要求
#  - 你可以进行任意长度的思考, 然后用<CODE></CODE>包裹你的代码.
#  - 你需要按照下面这个框架编写代码:
#   - 1. 标记valid的subject(cu_n_k_subject); (复合subject的行标记为True, 不符合的为False)
#   - 2. 标记valid的condition(cu_n_k_condition); (符合condition的行标记为True, 不符合的为False)
#   - 3. 标记valid的constraint(cu_n_k_constraint); (符合constraint的行标记为True, 不符合的为False)
#   - 4. 在dataframe中记录subject, condition和constraint的valid情况;
#  - 注意: 对于简单操作dataframe就可以处理的项目, 对三元组<subject, conditon, constraint>的检查是各自独立的, 你需要分别标记三元组的True和False. 并不是只对符合subject和condition进行检查. 对于需要调用llm_content_check()函数的项目, 只对符合<subject, conditon>的constraint进行检查.
#
# # example
# 下面是一个例子:
#
# ## 输入
# 法律的合规单元编号: cu_4_1
# 法律的合规单元内容: {"subject": "上市公司大股东 | 董监高", "condition": "计划通过本所集中竞价或大宗交易减持股份", "constraint": "应当及时通知公司，并在首次卖出的15个交易日前向本所报告并预先披露减持计划", "contextual_info": NaN}
# 必要的额外信息: NaN
#
# ## 输出
# <CODE>
# import pandas a pd
#
# def check_cu_4_1(df):
#     '''
#     检查cu_4_1的合规性：
#     主体：上市公司大股东 | 董监高
#     条件：存在通过竞价/大宗交易的减持计划
#     约束：首次卖出前至少15个交易日披露
#     '''
#     df = df.copy()
#
#     # 初始化标记列
#     df['cu_4_1_subject'] = False
#     df['cu_4_1_condition'] = False
#     df['cu_4_1_constraint'] = None
#
#     # 1. 验证责任主体
#     is_major = (
#         df['股东身份'].isin(['控股股东', '实际控制人', '持股5%以上股东']) |
#         (df['持股比例'] >= 0.05)
#     )
#     is_director = df['股东身份'] == '董监高'
#     df.loc[is_major | is_director, 'cu_4_1_subject'] = True
#
#     # 2. 验证触发条件
#     valid_condition = (
#         df['减持方式'].isin(['竞价交易', '大宗交易']) &
#         df['存在减持计划']
#     )
#     df.loc[valid_condition, 'cu_4_1_condition'] = True
#
#     # 3. 核心改进：准确识别首次卖出日
#     def process_group(group):
#         group = group.sort_values('日期')
#         plans = []
#         current_plan = None
#
#         # 识别减持计划区间
#         for _, row in group.iterrows():
#             if row['存在减持计划']:
#                 if current_plan is None:
#                     current_plan = {
#                         '披露日': row['计划披露日'],
#                         '开始日': row['计划开始日'],
#                         '减持记录': []
#                     }
#                 if row['当日减持比例'] > 0:
#                     current_plan['减持记录'].append(row['日期'])
#             else:
#                 if current_plan:
#                     plans.append(current_plan)
#                     current_plan = None
#         if current_plan:
#             plans.append(current_plan)
#
#         # 提取首次卖出日
#         return pd.DataFrame([{
#             '公司简称': group['公司简称'].iloc[0],
#             '股东': group['股东'].iloc[0],
#             '计划披露日': p['披露日'],
#             '首次卖出日': min(p['减持记录']) if p['减持记录'] else pd.NaT
#         } for p in plans])
#
#     # 按分组处理并合并
#     plan_info = df.groupby(['公司简称', '股东'], group_keys=False).apply(process_group)
#     df = df.merge(
#         plan_info,
#         on=['公司简称', '股东', '计划披露日'],
#         how='left'
#     ) if not plan_info.empty else df.assign(首次卖出日=pd.NaT)
#
#     # 4. 交易日差计算（改进点：使用首次卖出日而非计划开始日）
#     trading_dates = pd.Series(df['日期'].unique()).sort_values().reset_index(drop=True)
#     date_map = {date: idx for idx, date in enumerate(trading_dates)}
#
#     df['交易日差'] = df.apply(
#         lambda x: date_map.get(x['首次卖出日'], np.nan) - date_map.get(x['计划披露日'], np.nan),
#         axis=1
#     )
#
#     # 5. 验证约束条件
#     # 至少提前15个交易日披露
#     df['cu_4_1_constraint'] = (df['交易日差'] >= 15)
#
#     return df
#
# </CODE>
#
# # 下面轮到你来完成这个任务
# 法律的最小可执行单元编号: cu_9_3
# 法律的最小可执行单元内容: {"subject": "董监高", "condition": "在前款规定的2个完整会计年度期间内离职", "constraint": "应当继续遵守前款规定的减持限制", "contextual_info": NaN}
# 必要的额外信息: 只需要检查subject和condition, 而constraint项留为None
#
# 你被分配的cu coding任务存在refer_to关系, 你需要参考下面这个cu的必要内容来完成你被安排的任务, 但你不需要直接执行下面的cu:
# 参考条目：MEU_9_1
#
#
# # 附加信息
# ## 你可以操作的dataframe的columns:
# ['日期', '日收益率', '收盘价', '前收盘价', '上市日期', '发行价格', '净资产增长率', '净利润增长率', '净资产',
# '净利润', '总股本', '每股净资产', '每股净利润', '公告类型', '公告日期', '复权因子', '收盘价减每股净资产',
# '收盘价减每股净利润', '公司涉嫌证券期货违法犯罪事件', '持股比例', '持股数量', '股东身份', '减持方式', '拟减持原因',
# '存在减持计划', '计划减持比例', '计划价格下限', '计划价格上限', '当日减持比例', '累计减持比例', '计划披露日',
# '计划开始日', '计划结束日', '离任日期', '公司简称', '股东', '股东涉嫌证券期货违法犯罪事件']
#
# ## 其中:
# - 所有公司均为在本交易所上市的上市公司
# - 所有日期相关的列都已经是pd.datetime格式, ['日期']列本身就是交易日, 不需要额外计算交易日, 但是自然日需要计算.
# - 所有价格的单位都是元而非万元, 千元或百万元; 所有的比例都是小数而非百分数
# - 这是一个二维的面板数据, 根据['日期', '公司简称', '股东']可以定位到特定公司的特定股东在特定交易日的状态, 以及公司在该日的状态. 如果你要分公司和股东地考虑一些合规要求, 需要考虑按照 ['公司简称', '股东']分组并在组内完成.
# - 交易方式有['竞价交易', '大宗交易', '融券卖出'], 竞价交易包括集中竞价.
# - ['公司/股东涉嫌证券期货违法犯罪事件'] 有['被中国证监会及其派出机构立案调查', '中国证监会及其派出机构立案调查结束', '行政处罚决定作出', '被司法机关立案侦查', '司法机关立案侦查结束', '被本所公开谴责']
# - ['股东身份'] 有 ['董监高', '离任董监高', '控股股东', '实际控制人', '持股5%以上股东', '普通股东'], 这些标签不会并列出现, 因此有时候董监高/离任董监高持股在5%以上但并没有标明'持股5%以上股东', 你需要从['持股比例']手动筛选.
# - ['存在减持计划']是一个布尔值，表示该股东当天是否有减持计划
# - 假设公司上市发行价就是最早的非空的收盘价, 公司发行时的控股股东和实际控制人就是第一个非空的收盘价的同一天的控股股东和实际控制人.
# - ['持股比例'] 全部是公开上市前取得的股份. 不考虑承诺和限制出售的股份.
#
#
# --------------------------------------------------
#
# # 身份
# 你是一个精通法律的程序员. 擅长编写代码以检验特定案例对于特定法律要求的合规性.
#
# ## ComplianceUnit概念简述
# ComplianceUnit是法律条文拆解出的合规检查单元，包含：
# - cu_id: ComplianceUnit的编号, 通常为"cu_n_k", 其中n是其所属的法条的编号, k是其在法条内部的编号
# - subject: 责任主体（如"控股股东")
# - condition: 触发条件（如"减持股份")
# - constraint: 约束内容（如"提前15日公告")
# - contextual_info: 补充说明（如价格计算方式）
#
#
# # 任务
# 你现在面临一个编写代码以检验某法律事件的合规性的任务, 你需要编写一个函数, 这个函数的输入是一个日频的pandas dataframe, 每一行是在某个交易日内公司的情况和股东的情况, 这个函数会检验该dataframe的每一行在某一个给定的法律合规单元上的合规性, 标注在特定的列上, 并返回标注后的dataframe.
#
#
# # 更多要求
#  - 你可以进行任意长度的思考, 然后用<CODE></CODE>包裹你的代码.
#  - 你需要按照下面这个框架编写代码:
#   - 1. 标记valid的subject(cu_n_k_subject); (复合subject的行标记为True, 不符合的为False)
#   - 2. 标记valid的condition(cu_n_k_condition); (符合condition的行标记为True, 不符合的为False)
#   - 3. 标记valid的constraint(cu_n_k_constraint); (符合constraint的行标记为True, 不符合的为False)
#   - 4. 在dataframe中记录subject, condition和constraint的valid情况;
#  - 注意: 对于简单操作dataframe就可以处理的项目, 对三元组<subject, conditon, constraint>的检查是各自独立的, 你需要分别标记三元组的True和False. 并不是只对符合subject和condition进行检查. 对于需要调用llm_content_check()函数的项目, 只对符合<subject, conditon>的constraint进行检查.
#
# # example
# 下面是一个例子:
#
# ## 输入
# 法律的合规单元编号: cu_4_1
# 法律的合规单元内容: {"subject": "上市公司大股东 | 董监高", "condition": "计划通过本所集中竞价或大宗交易减持股份", "constraint": "应当及时通知公司，并在首次卖出的15个交易日前向本所报告并预先披露减持计划", "contextual_info": NaN}
# 必要的额外信息: NaN
#
# ## 输出
# <CODE>
# import pandas a pd
#
# def check_cu_4_1(df):
#     '''
#     检查cu_4_1的合规性：
#     主体：上市公司大股东 | 董监高
#     条件：存在通过竞价/大宗交易的减持计划
#     约束：首次卖出前至少15个交易日披露
#     '''
#     df = df.copy()
#
#     # 初始化标记列
#     df['cu_4_1_subject'] = False
#     df['cu_4_1_condition'] = False
#     df['cu_4_1_constraint'] = None
#
#     # 1. 验证责任主体
#     is_major = (
#         df['股东身份'].isin(['控股股东', '实际控制人', '持股5%以上股东']) |
#         (df['持股比例'] >= 0.05)
#     )
#     is_director = df['股东身份'] == '董监高'
#     df.loc[is_major | is_director, 'cu_4_1_subject'] = True
#
#     # 2. 验证触发条件
#     valid_condition = (
#         df['减持方式'].isin(['竞价交易', '大宗交易']) &
#         df['存在减持计划']
#     )
#     df.loc[valid_condition, 'cu_4_1_condition'] = True
#
#     # 3. 核心改进：准确识别首次卖出日
#     def process_group(group):
#         group = group.sort_values('日期')
#         plans = []
#         current_plan = None
#
#         # 识别减持计划区间
#         for _, row in group.iterrows():
#             if row['存在减持计划']:
#                 if current_plan is None:
#                     current_plan = {
#                         '披露日': row['计划披露日'],
#                         '开始日': row['计划开始日'],
#                         '减持记录': []
#                     }
#                 if row['当日减持比例'] > 0:
#                     current_plan['减持记录'].append(row['日期'])
#             else:
#                 if current_plan:
#                     plans.append(current_plan)
#                     current_plan = None
#         if current_plan:
#             plans.append(current_plan)
#
#         # 提取首次卖出日
#         return pd.DataFrame([{
#             '公司简称': group['公司简称'].iloc[0],
#             '股东': group['股东'].iloc[0],
#             '计划披露日': p['披露日'],
#             '首次卖出日': min(p['减持记录']) if p['减持记录'] else pd.NaT
#         } for p in plans])
#
#     # 按分组处理并合并
#     plan_info = df.groupby(['公司简称', '股东'], group_keys=False).apply(process_group)
#     df = df.merge(
#         plan_info,
#         on=['公司简称', '股东', '计划披露日'],
#         how='left'
#     ) if not plan_info.empty else df.assign(首次卖出日=pd.NaT)
#
#     # 4. 交易日差计算（改进点：使用首次卖出日而非计划开始日）
#     trading_dates = pd.Series(df['日期'].unique()).sort_values().reset_index(drop=True)
#     date_map = {date: idx for idx, date in enumerate(trading_dates)}
#
#     df['交易日差'] = df.apply(
#         lambda x: date_map.get(x['首次卖出日'], np.nan) - date_map.get(x['计划披露日'], np.nan),
#         axis=1
#     )
#
#     # 5. 验证约束条件
#     # 至少提前15个交易日披露
#     df['cu_4_1_constraint'] = (df['交易日差'] >= 15)
#
#     return df
#
# </CODE>
#
# # 下面轮到你来完成这个任务
# 法律的最小可执行单元编号: cu_17_1
# 法律的最小可执行单元内容: {"subject": "上市公司董监高 | 离任六个月内的董监高", "condition": "每年通过集中竞价、大宗交易、协议转让等方式转让股份且不属于因司法强制执行、继承、遗赠、依法分割财产等导致股份变动", "constraint": "每年转让的股份不得超过其所持本公司股份总数的25%", "contextual_info": NaN}
# 必要的额外信息: 不考虑因司法强制执行、继承、遗赠、依法分割财产等导致股份变动的情况; 6个月按180个自然日计算, 含处罚日当日; 年按照自然年计算; 计算持股数量限制时以持股比例为准, 而非绝对数量.
#
# 你被分配的cu coding任务存在refer_to关系, 你需要参考下面这个cu的必要内容来完成你被安排的任务, 但你不需要直接执行下面的cu:
# 参考条目：MEU_18_1
#
# 参考条目：MEU_18_2
#
# 参考条目：MEU_18_3
#
# 参考条目：MEU_18_4
#
#
# # 附加信息
# ## 你可以操作的dataframe的columns:
# ['日期', '日收益率', '收盘价', '前收盘价', '上市日期', '发行价格', '净资产增长率', '净利润增长率', '净资产',
# '净利润', '总股本', '每股净资产', '每股净利润', '公告类型', '公告日期', '复权因子', '收盘价减每股净资产',
# '收盘价减每股净利润', '公司涉嫌证券期货违法犯罪事件', '持股比例', '持股数量', '股东身份', '减持方式', '拟减持原因',
# '存在减持计划', '计划减持比例', '计划价格下限', '计划价格上限', '当日减持比例', '累计减持比例', '计划披露日',
# '计划开始日', '计划结束日', '离任日期', '公司简称', '股东', '股东涉嫌证券期货违法犯罪事件']
#
# ## 其中:
# - 所有公司均为在本交易所上市的上市公司
# - 所有日期相关的列都已经是pd.datetime格式, ['日期']列本身就是交易日, 不需要额外计算交易日, 但是自然日需要计算.
# - 所有价格的单位都是元而非万元, 千元或百万元; 所有的比例都是小数而非百分数
# - 这是一个二维的面板数据, 根据['日期', '公司简称', '股东']可以定位到特定公司的特定股东在特定交易日的状态, 以及公司在该日的状态. 如果你要分公司和股东地考虑一些合规要求, 需要考虑按照 ['公司简称', '股东']分组并在组内完成.
# - 交易方式有['竞价交易', '大宗交易', '融券卖出'], 竞价交易包括集中竞价.
# - ['公司/股东涉嫌证券期货违法犯罪事件'] 有['被中国证监会及其派出机构立案调查', '中国证监会及其派出机构立案调查结束', '行政处罚决定作出', '被司法机关立案侦查', '司法机关立案侦查结束', '被本所公开谴责']
# - ['股东身份'] 有 ['董监高', '离任董监高', '控股股东', '实际控制人', '持股5%以上股东', '普通股东'], 这些标签不会并列出现, 因此有时候董监高/离任董监高持股在5%以上但并没有标明'持股5%以上股东', 你需要从['持股比例']手动筛选.
# - ['存在减持计划']是一个布尔值，表示该股东当天是否有减持计划
# - 假设公司上市发行价就是最早的非空的收盘价, 公司发行时的控股股东和实际控制人就是第一个非空的收盘价的同一天的控股股东和实际控制人.
# - ['持股比例'] 全部是公开上市前取得的股份. 不考虑承诺和限制出售的股份.

# %%
len(prompt_list)
# Out:
# 31

# %% [markdown]
# # 异步调用LLM

# %%
import asyncio
from tqdm.asyncio import tqdm_asyncio
import pandas as pd
import os
from utils.call_gpt import call_gpt_async 

async def process_prompts_async(
    prompt_list,
    output_file_path,
    max_concurrency=5,
):
    """
    异步处理prompt列表并保存结果到Excel文件
    
    参数：
    prompt_list: 提示词字符串列表
    output_file_path: 输出文件路径
    max_concurrency: 最大并行请求数（默认5）
    """
    
    # 确保输出目录存在
    os.makedirs(os.path.dirname(output_file_path), exist_ok=True)
    
    # 共享状态
    results = []
    failed_prompts = []
    semaphore = asyncio.Semaphore(max_concurrency)

    async def process_single_prompt(prompt):
        """处理单个提示词的异步任务"""
        async with semaphore:
            try:
                content, reasoning_content, api_usage = await call_gpt_async(
                    prompt=prompt,
                    api_key=your_api_key,
                    base_url=your_api_base,
                    model=your_model_name,
                    # temperature=0.6,
                )

                return {
                    "prompt": prompt,
                    "response": content,
                    "reasoning_content": reasoning_content,
                    "api_usage": api_usage
                }
            except Exception as e:
                failed_prompts.append(prompt)
                print(f"Error processing prompt: {str(e)}")
                return None

    # 创建所有任务
    tasks = [process_single_prompt(prompt) for prompt in prompt_list]
    
    # 执行并带进度条
    pbar = tqdm_asyncio(total=len(tasks), desc="Processing prompts")
    
    for future in asyncio.as_completed(tasks):
        result = await future
        if result:
            results.append(result)
        pbar.update()

    pbar.close()

    # 将结果转换为DataFrame并保存为Excel
    df = pd.DataFrame(results)
    df.to_csv(output_file_path, index=False)

    # 打印简要报告
    print(f"\nSuccess: {len(results)}")
    print(f"Failed: {len(failed_prompts)}")

    return failed_prompts
# Out:
# OPENAI_API_KEY未配置, 你需要在调用call_gpt函数时传参

# %%
failed_prompts = await process_prompts_async(
    prompt_list,
    output_file_path="ComplianceUnit_to_code/ComplianceUnit_code/raw_response/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.csv",
    max_concurrency=10
)
# Out:
# Processing prompts: 100%|██████████| 31/31 [17:26<00:00, 33.76s/it]
# Success: 31
# Failed: 0

# %% [markdown]
# # 解析出代码并保存

# %%
import pandas as pd
import re

# 读取原始Excel文件
input_path = "ComplianceUnit_to_code/ComplianceUnit_code/raw_response/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.csv"
df = pd.read_csv(input_path)

# 定义一个函数来提取<CODE>标签中的内容
def extract_code(text):
    if not isinstance(text, str):
        return ""
    
    # 处理<\CODE>的错误格式，统一替换为</CODE>
    text = text.replace('<\\CODE>', '</CODE>')
    
    # 使用正则表达式提取所有<CODE>...</CODE>之间的内容
    code_blocks = re.findall(r'<CODE>(.*?)</CODE>', text, re.DOTALL)
    
    # 将所有代码块合并，用两个换行符分隔
    return '\n\n'.join(code_blocks).strip()

# 应用函数提取代码
df['code'] = df['response'].apply(extract_code)

# 保存到新的Excel文件
output_path = "ComplianceUnit_to_code/ComplianceUnit_code/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.xlsx"
df.to_excel(output_path, index=False)

print(f"处理完成，结果已保存到: {output_path}")
# Out:
# 处理完成，结果已保存到: ComplianceUnit_to_code/ComplianceUnit_code/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.xlsx

# %%
import pandas as pd
import re
import ast  # 用于安全地解析字符串表达式

def parse_api_usage(api_usage_str):
    """
    解析api_usage字符串，提取prompt_tokens和completion_tokens
    示例输入: "CompletionUsage(completion_tokens=515, prompt_tokens=1649, total_tokens=2164, ...)"
    """
    if not isinstance(api_usage_str, str) or not api_usage_str.startswith("CompletionUsage"):
        return pd.Series({'prompt_tokens': None, 'completion_tokens': None})
    
    try:
        # 安全地解析字符串为字典
        # 首先提取括号内的内容
        content = api_usage_str.split('(', 1)[1].rsplit(')', 1)[0]
        # 创建一个字典来保存键值对
        params = {}
        # 分割键值对
        for item in content.split(','):
            item = item.strip()
            if '=' in item:
                key, value = item.split('=', 1)
                key = key.strip()
                # 只处理我们需要的键
                if key in ['prompt_tokens', 'completion_tokens']:
                    # 尝试转换为整数
                    try:
                        params[key] = int(value)
                    except ValueError:
                        params[key] = None
        return pd.Series({
            'prompt_tokens': params.get('prompt_tokens'),
            'completion_tokens': params.get('completion_tokens')
        })
    except Exception as e:
        print(f"解析api_usage时出错: {e}")
        return pd.Series({'prompt_tokens': None, 'completion_tokens': None})

def enrich_response_with_original_info():
    """
    读取模型回复文件，并根据prompt_dict_cache的cu_id从原始信息文件中获取额外信息，
    然后合并保存到原文件，同时解析api_usage提取token信息
    """
    # 读取模型回复文件
    response_path = "ComplianceUnit_to_code/ComplianceUnit_code/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.xlsx"
    response_df = pd.read_excel(response_path)
    
    # 解析api_usage列
    token_info = response_df['api_usage'].apply(parse_api_usage)
    response_df = pd.concat([response_df, token_info], axis=1)
    
    # 读取原始信息文件
    info_path = "ComplianceUnit_to_code/ComplianceUnit_selected_with_relation_GT/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.xlsx"
    info_df = pd.read_excel(info_path)
    
    # 统一constrain/constraint列名为constrain
    for col in info_df.columns:
        if col.lower() in ['constrain', 'constraint']:
            info_df.rename(columns={col: 'constrain'}, inplace=True)
    
    # 确保我们有prompt_dict_cache
    global _prompt_dict_cache
    if _prompt_dict_cache is None:
        raise ValueError("prompt_dict_cache未初始化，请先运行prepare_prompts函数")
    
    # 创建一个cu_id到prompt的反向映射
    prompt_to_cu_id = {v: k for k, v in _prompt_dict_cache.items()}
    
    # 从prompt列提取cu_id
    response_df['cu_id'] = response_df['prompt'].map(prompt_to_cu_id)
    
    # 合并原始信息
    merged_df = response_df.merge(
        info_df[['cu_id', 'subject', 'condition', 'constrain', 
                'contextual_info', 'relation', 'target', 'type', 'comments', 'note']],
        on='cu_id',
        how='left'
    )
    
    # 重新排列列顺序
    columns_order = [
        'cu_id', 'subject', 'condition', 'constrain', 'contextual_info',
        'relation', 'target', 'type', 'comments', 'note',
        'prompt_tokens', 'completion_tokens',
        'prompt', 'response', 'reasoning_content', 'api_usage', 'code'
    ]
    # 只保留存在的列
    columns_order = [col for col in columns_order if col in merged_df.columns]
    merged_df = merged_df[columns_order]
    
    # 保存回原文件
    merged_df.to_excel(response_path, index=False)
    print(f"处理完成，结果已保存到: {response_path}")

# 示例使用方式：
# 1. 首先确保已经初始化了prompt_dict_cache
# 2. 然后调用这个函数
enrich_response_with_original_info()
# Out:
# 处理完成，结果已保存到: ComplianceUnit_to_code/ComplianceUnit_code/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.xlsx

# %% [markdown]
# # 保存到ipynb方便查看

# %%
import pandas as pd
import nbformat
from nbformat.v4 import new_notebook, new_markdown_cell, new_code_cell
import re

# 读取Excel文件
input_path = "ComplianceUnit_to_code/ComplianceUnit_code/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.xlsx"
df = pd.read_excel(input_path)

# 创建新的Notebook
notebook = new_notebook()

# 在最上方添加读取CSV文件的代码单元格
notebook.cells.append(new_code_cell("""# 读取模拟数据
import pandas as pd
df = pd.read_csv('data_simulation/data_generated/data_simulate_08.csv')
date_columns = ['日期', '上市日期', '公告日期', '计划披露日', '计划开始日', '计划结束日', '离任日期']
for col in date_columns:
    df[col] = pd.to_datetime(df[col])
df"""))

def extract_function_name(code):
    """
    从代码中提取函数名
    例如：从 'def check_cu_13_3(df):' 提取 'check_cu_13_3'
    """
    match = re.search(r'def\s+([a-zA-Z_]\w*)\s*\(', code)
    return match.group(1) if match else None

# 提取法条号(n)和cu序号(k)用于排序
def extract_n(x):
    match = re.match(r'cu_(\d+)_\d+', str(x))
    return int(match.group(1)) if match else 0

def extract_k(x):
    match = re.match(r'cu_\d+_(\d+)', str(x))
    return int(match.group(1)) if match else 0

df['cu_n'] = df['cu_id'].apply(extract_n)
df['cu_k'] = df['cu_id'].apply(extract_k)

# 按法条号(n)和cu序号(k)排序
df = df.sort_values(['cu_n', 'cu_k'])

# 遍历每个cu（已排序）
current_n = None
for _, row in df.iterrows():
    # 如果法条号变化，添加一级标题
    if row['cu_n'] != current_n:
        notebook.cells.append(new_markdown_cell(f"# Law Article {row['cu_n']}"))
        current_n = row['cu_n']
    
    # 添加二级标题（cu编号）
    notebook.cells.append(new_markdown_cell(f"## {row['cu_id']}"))
    
    # 创建cu信息表格
    info_table = f"""
| 字段 | 内容 |
|------|------|
| subject | {row['subject'] or ''} |
| condition | {row['condition'] or ''} |
| constrain | {row['constrain'] or ''} |
| contextual_info | {row['contextual_info'] or ''} |
| note | {row['note'] or ''} |
| relation | {row['relation'] or ''} |
| target | {row['target'] or ''} |
| type | {row['type'] or ''} |
| comments | {row['comments'] or ''} |
| prompt_tokens | {row['prompt_tokens'] or ''} |
| completion_tokens | {row['completion_tokens'] or ''} |
"""
    notebook.cells.append(new_markdown_cell(info_table))
    
    # # 添加reasoning_content
    # if pd.notna(row['reasoning_content']):
    #     notebook.cells.append(new_markdown_cell("### 推理内容"))
    #     notebook.cells.append(new_markdown_cell(str(row['reasoning_content'])))
    
    # 添加代码单元格
    if pd.notna(row['code']):
        notebook.cells.append(new_markdown_cell("### 代码实现"))
        notebook.cells.append(new_code_cell(str(row['code'])))

        # 提取函数名并添加调用函数的代码单元格
        function_name = extract_function_name(str(row['code']))
        if function_name:
            notebook.cells.append(new_code_cell(f"df = {function_name}(df)\ndf"))
    
    # 添加分隔线
    notebook.cells.append(new_markdown_cell("---"))

# 保存Notebook文件
output_path = "ComplianceUnit_to_code/ComplianceUnit_code/view_ipynb/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.ipynb"
with open(output_path, 'w', encoding='utf-8') as f:
    nbformat.write(notebook, f)

print(f"Jupyter Notebook已成功生成: {output_path}")
# Out:
# Jupyter Notebook已成功生成: ComplianceUnit_to_code/ComplianceUnit_code/view_ipynb/北京证券交易所上市公司持续监管指引第8号——股份减持和持股管理.ipynb
